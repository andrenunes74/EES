# %%
# estatísticas básicas
import seaborn as sea
import scipy.stats as stats
import matplotlib.pyplot as plt
import pandas as pd


file_name = 'final.csv'
df = pd.read_csv(file_name, header = 0, delimiter=",", decimal=".", names=['Program','Package','Core(s)','GPU','DRAM?','Time(sec)','Peak Memory Usage (KB)','PowerCap(uW)'])
plt.figure(figsize=(10,6))
sea.scatterplot(data=df,hue='Program',x='Package', y='Time(sec)')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)

df = pd.read_csv(file_name, header = 0, delimiter=",", decimal=".", names=['Program','Package','Core(s)','GPU','DRAM?','Time(sec)','Peak Memory Usage (KB)','PowerCap(uW)'])
plt.figure(figsize=(10,6))
sea.scatterplot(data=df,hue='Program',x='Peak Memory Usage (KB)', y='Time(sec)')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)

df = pd.read_csv(file_name, header = 0, delimiter=",", decimal=".", names=['Program','Package','Core(s)','GPU','DRAM?','Time(sec)','Peak Memory Usage (KB)','PowerCap(uW)'])
plt.figure(figsize=(10,6))
sea.scatterplot(data=df,hue='Program',x='PowerCap(uW)', y='Package')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)

df = pd.read_csv(file_name, header = 0, delimiter=",", decimal=".", names=['Program','Package','Core(s)','GPU','DRAM?','Time(sec)','Peak Memory Usage (KB)','PowerCap(uW)'])
plt.figure(figsize=(10,6))
sea.scatterplot(data=df,hue='Program',x='PowerCap(uW)', y='Time(sec)')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)


df = pd.read_csv(file_name, header = 0, delimiter=",", decimal=".", names=['Program','Package','Core(s)','GPU','DRAM?','Time(sec)','Peak Memory Usage (KB)','PowerCap(uW)'])
plt.figure(figsize=(10,6))
sea.scatterplot(data=df,hue='Program',x='PowerCap(uW)', y='Peak Memory Usage (KB)')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)

# estatísticas básicas (descritivas)
# summary stats
print("Stats")
print(df[["Time(sec)","GPU","Package"]].describe())
print()
print(df.groupby("Program")[["GPU","Time(sec)"]].describe())

print("Stats")
print(df[["Time(sec)","Core(s)","Package"]].describe())
print()
print(df.groupby("Program")[["Core(s)","Time(sec)"]].describe())

print("Stats")
print(df[["Time(sec)","Peak Memory Usage (KB)","Package"]].describe())
print()
print(df.groupby("Program")[["Peak Memory Usage (KB)","Time(sec)"]].describe())

print("Stats")
print(df[["Time(sec)","PowerCap(uW)","Package"]].describe())
print()
print(df.groupby("Program")[["PowerCap(uW)","Time(sec)"]].describe())
# Out:
# Stats
#           Time(sec)         GPU      Package
# count  9.600000e+02  960.000000   960.000000
# mean   1.487099e+07    0.381086   230.298443
# std    2.051261e+07    1.312860   318.061215
# min    2.268000e+03    0.000000     0.018555
# 25%    1.363482e+05    0.025376     1.988373
# 50%    2.514410e+06    0.067597    39.186920
# 75%    2.611242e+07    0.290619   407.729950
# max    7.562040e+07   24.800171  1357.675720
#
#                               GPU                                          \
#                             count      mean       std       min       25%
# Program
# exe/bubbleSort 10000         40.0  0.027284  0.010462  0.013794  0.019378
# exe/bubbleSort 20000         40.0  0.065587  0.096267  0.015015  0.025879
# exe/bubbleSort 30000         40.0  0.090836  0.151405  0.031006  0.039475
# exe/bubbleSort.py 10000      40.0  3.103986  5.442945  0.269836  0.491608
# exe/bubbleSort.py 20000      40.0  1.014812  0.850041  0.446655  0.493194
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

file_name = 'final.csv'
df = pd.read_csv(file_name, header=0, delimiter=",", decimal=".", names=['Program', 'Package', 'Core(s)', 'GPU', 'DRAM?', 'Time(sec)', 'Peak Memory Usage (KB)', 'PowerCap(uW)'])

plt.figure(figsize=(10, 6))

# Create histogram
sns.histplot(data=df, hue='Program', x='Package', multiple='stack', alpha=0.6)

# Perform kernel density estimation and plot
for program in df['Program'].unique():
    sns.kdeplot(data=df[df['Program'] == program], x='Package', label=program)

plt.xlabel('Package')
plt.title('Histogram and Kernel Density Estimation of Package')

# Move legend outside the plot
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

file_name = 'final.csv'
df = pd.read_csv(file_name, header=0, delimiter=",", decimal=".", names=['Program', 'Package', 'Core(s)', 'GPU', 'DRAM?', 'Time(sec)', 'Peak Memory Usage (KB)', 'PowerCap(uW)'])

plt.figure(figsize=(10, 6))

# Create histogram
sns.histplot(data=df, hue='Program', x='Time(sec)', multiple='stack', alpha=0.6)

# Perform kernel density estimation and plot
for program in df['Program'].unique():
    sns.kdeplot(data=df[df['Program'] == program], x='Time(sec)', label=program)

plt.xlabel('Time(sec)')
plt.title('Histogram and Kernel Density Estimation of Time(sec)')

# Move legend outside the plot
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %%
# Histogram and density estimation
from sklearn.neighbors import KernelDensity
import numpy as py
import seaborn as sea
import scipy.stats as stats
import matplotlib.pyplot as plt
import pandas as pd

file_name = 'final.csv'
df = pd.read_csv(file_name, header = 0, delimiter=",", decimal=".", names=['Program','Package','Core(s)','GPU','DRAM?','Time(sec)','Peak Memory Usage (KB)','PowerCap(uW)'])

plt.figure(figsize=(10,6))
sea.histplot(data=df,hue='Program',x='GPU')
sea.kdeplot(data=df,hue='Program',x='GPU') # kernel density estimation for distr
# Out:
# <AxesSubplot:xlabel='GPU', ylabel='Count'>

# %%
# Histogram and density estimation
from sklearn.neighbors import KernelDensity
import numpy as py
import matplotlib.pyplot as plt


file_name = 'final.csv'
df = pd.read_csv(file_name, header = 0, delimiter=",", decimal=".", names=['Program','Package','Core(s)','GPU','DRAM?','Time(sec)','Peak Memory Usage (KB)','PowerCap(uW)'])

courses = list(df['Package'])
values = list(df['Time(sec)'])
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(courses, values, color ='blue',
        width = 0.4)
 
plt.xlabel("Package")
plt.ylabel("Time(sec)")
plt.title("Package vs Time")
plt.show()

# %%
# Histogram and density estimation
from sklearn.neighbors import KernelDensity
import numpy as py
import matplotlib.pyplot as plt


file_name = 'final.csv'
df = pd.read_csv(file_name, header = 0, delimiter=",", decimal=".", names=['Program','Package','Core(s)','GPU','DRAM?','Time(sec)','Peak Memory Usage (KB)','PowerCap(uW)'])

courses = list(df['Package'])
values = list(df['GPU'])
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(courses, values, color ='blue',
        width = 0.4)
 
plt.xlabel("Package")
plt.ylabel("GPU")
plt.title("GPU vs Time")
plt.show()

# %% [markdown]
# ------------------------------------------------------------------------------------------------

# %%
file_name = 'final.csv'
df = pd.read_csv(file_name, header = 0, delimiter=",", decimal=".", names=['Program','Package','Core(s)','GPU','DRAM?','Time(sec)','Peak Memory Usage (KB)','PowerCap(uW)'])
plt.figure(figsize=(20, 8))
sea.boxplot(data=df,hue='Program',x='Time(sec)',y='Program',medianprops={"color":"red"},
            flierprops={"marker": "."},)
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)

# %%
#  Pearson Corr Coef

p = stats.pearsonr(df['GPU'], df['Package'])
"""Aqui pvalue é usado no sentido da prob de encontrar
 este resultado se de facto PearsonCorr fosse = 0.
 Se pvalue < 0.05 então a correlation é significativa
 """
print(p)

ro, pvalue1 = stats.spearmanr(df['GPU'], df['Package'])
tau, pvalue2 = stats.kendalltau(df['GPU'], df['Package'])
print("ro="+str(ro)  +"  p="+ str(pvalue1))
print("tau="+str(tau)+"  p="+str(pvalue2))

plt.figure(figsize=(10,6))
plt.title('Correlação entre GPU e Package')
 
# plot the data
plt.scatter(df.GPU, df.Package)
 
# fits the best fitting line to the data
plt.plot(py.unique(df.GPU),
         py.poly1d(py.polyfit(df.GPU, df.Package, 1))
         (py.unique(df.GPU)), color='red')
 
# Labelling axes
plt.xlabel('GPU ')
plt.ylabel('Package ')
# Out:
# (0.4531319335848966, 8.771044851277292e-50)
# ro=0.9144686623695821  p=0.0
# tau=0.7616228793478338  p=6.800161164931475e-273
# Text(0, 0.5, 'Package ')

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

file_name = 'final.csv'
df = pd.read_csv(file_name, header=0, delimiter=",", decimal=".", names=['Program', 'Package', 'Core(s)', 'GPU', 'DRAM?', 'Time(sec)', 'Peak Memory Usage (KB)', 'PowerCap(uW)'])

p = stats.pearsonr(df['Time(sec)'], df['Package'])
"""
Aqui pvalue é usado no sentido da prob de encontrar
este resultado se de facto PearsonCorr fosse = 0.
Se pvalue < 0.05 então a correlation é significativa
"""
print(p)

ro, pvalue1 = stats.spearmanr(df['Time(sec)'], df['Package'])
tau, pvalue2 = stats.kendalltau(df['Time(sec)'], df['Package'])
print("ro=" + str(ro) + "  p=" + str(pvalue1))
print("tau=" + str(tau) + "  p=" + str(pvalue2))

plt.figure(figsize=(10, 6))
plt.title('Correlação entre Time(sec) e Package')

# plot the data
plt.scatter(df['Time(sec)'], df['Package'])

# fits the best fitting line to the data
plt.plot(np.unique(df['Time(sec)']), np.poly1d(np.polyfit(df['Time(sec)'], df['Package'], 1))(np.unique(df['Time(sec)'])), color='red')

# Labeling axes
plt.xlabel('Time(sec)')
plt.ylabel('Package')

plt.show()
# Out:
# (0.9960465580872906, 0.0)
# ro=0.9779669374752223  p=0.0
# tau=0.8791497894771624  p=0.0

# %% [markdown]
# ------------------------------------------------------------------------------------------------

# %% [markdown]
# Outliers e afins

# %%
# remoção de outliers via as ideias incluidas nos boxplot
# IQR - Inter Quartil Range como expresso os gráficos acima

# Como a distribuição é desconhecida vamos usar o IQR.
# Com Gaussianas podiamos usar outras estrategias. Mas há vários métodos...
import seaborn as sns

def remove_outliers_quantile(data_series):
    data = data_series
    q75, q25 = data.quantile(q=0.75),data.quantile(q=0.25) # np.percentile(data.loc[:,data_column],[75,25])
    intr_qr = q75 - q25

    max = q75 + (1.5 * intr_qr)
    min = q25 - (1.5 * intr_qr)

    count_total = len(data)

    data = data[(data > min) & (data < max)]
    count_wo_outliers = len(data)

    outliers_count = count_total - count_wo_outliers
    print(f'number of outliers: {outliers_count} of {count_total} observations.')
    
    # remove outliers
    return data


# create a subset of your data
# define the data source and how to separate the data
data = df
data_column = 'GPU'           # Atrib to compare
types_column_name = 'Program'    # The column name with the data in it
typeA = 'exe/selectionSort.py 30000 '      # The category of data A
typeB = 'exe/radixSort.py 30000 '     # The category of data B
typeC = 'exe/insertionSort.py 30000 '       # The category of data C
typeD = 'exe/bubbleSort.py 30000 '          # category D
typeE = 'exe/selectionSort.py 20000 '      # The category of data A
typeF = 'exe/radixSort.py 20000 '     # The category of data B
typeG = 'exe/insertionSort.py 20000 '       # The category of data C
typeH = 'exe/bubbleSort.py 20000 '          # category D
typeI = 'exe/selectionSort.py 10000 '      # The category of data A
typeJ = 'exe/radixSort.py 10000 '     # The category of data B
typeK = 'exe/insertionSort.py 10000 '       # The category of data C
typeL = 'exe/bubbleSort.py 10000 '          # category D
typeM = 'exe/selectionSort 30000 '      # The category of data A
typeN = 'exe/radixSort 30000 '     # The category of data B
typeO = 'exe/insertionSort 30000 '       # The category of data C
typeP = 'exe/bubbleSort 30000 '          # category D
typeQ = 'exe/selectionSort 20000 '      # The category of data A
typeR = 'exe/radixSort 20000 '     # The category of data B
typeS = 'exe/insertionSort 20000 '       # The category of data C
typeT = 'exe/bubbleSort 20000 '          # category D
typeU = 'exe/selectionSort 10000 '      # The category of data A
typeV = 'exe/radixSort 10000 '     # The category of data B
typeW = 'exe/insertionSort 10000 '       # The category of data C
typeX = 'exe/bubbleSort 10000 '          # category D



# create a new dataframe with the interesting subset 
df_sampleA = data[(data[types_column_name]==typeA)][data_column]
df_sampleB = data[(data[types_column_name]==typeB)][data_column]
df_sampleC = data[(data[types_column_name]==typeC)][data_column]
df_sampleD = data[(data[types_column_name]==typeD)][data_column]
df_sampleE = data[(data[types_column_name]==typeE)][data_column]
df_sampleF = data[(data[types_column_name]==typeF)][data_column]
df_sampleG = data[(data[types_column_name]==typeG)][data_column]
df_sampleH = data[(data[types_column_name]==typeH)][data_column]
df_sampleI = data[(data[types_column_name]==typeI)][data_column]
df_sampleJ = data[(data[types_column_name]==typeJ)][data_column]
df_sampleK = data[(data[types_column_name]==typeK)][data_column]
df_sampleL = data[(data[types_column_name]==typeL)][data_column]
df_sampleM = data[(data[types_column_name]==typeM)][data_column]
df_sampleN = data[(data[types_column_name]==typeN)][data_column]
df_sampleO = data[(data[types_column_name]==typeO)][data_column]
df_sampleP = data[(data[types_column_name]==typeP)][data_column]
df_sampleQ = data[(data[types_column_name]==typeQ)][data_column]
df_sampleR = data[(data[types_column_name]==typeR)][data_column]
df_sampleS = data[(data[types_column_name]==typeS)][data_column]
df_sampleT = data[(data[types_column_name]==typeT)][data_column]
df_sampleU = data[(data[types_column_name]==typeU)][data_column]
df_sampleV = data[(data[types_column_name]==typeV)][data_column]
df_sampleW = data[(data[types_column_name]==typeW)][data_column]
df_sampleX = data[(data[types_column_name]==typeX)][data_column]



# create a new dataframe with the interesting subset 
sampleA = list(df_sampleA)
sampleB = list(df_sampleB)
sampleC = list(df_sampleC)
sampleD = list(df_sampleD)
sampleE = list(df_sampleE)
sampleF = list(df_sampleF)
sampleG = list(df_sampleG)
sampleH = list(df_sampleH)
sampleI = list(df_sampleI)
sampleJ = list(df_sampleJ)
sampleK = list(df_sampleK)
sampleL = list(df_sampleL)
sampleM = list(df_sampleM)
sampleN = list(df_sampleN)
sampleO = list(df_sampleO)
sampleP = list(df_sampleP)
sampleQ = list(df_sampleQ)
sampleR = list(df_sampleR)
sampleS = list(df_sampleS)
sampleT = list(df_sampleT)
sampleU = list(df_sampleU)
sampleV = list(df_sampleV)
sampleW = list(df_sampleW)
sampleX = list(df_sampleX)

df_sampleA = remove_outliers_quantile(df_sampleA)
df_sampleB = remove_outliers_quantile(df_sampleB)
df_sampleC = remove_outliers_quantile(df_sampleC)
df_sampleD = remove_outliers_quantile(df_sampleD)
df_sampleE = remove_outliers_quantile(df_sampleE)
df_sampleF = remove_outliers_quantile(df_sampleF)
df_sampleG = remove_outliers_quantile(df_sampleG)
df_sampleH = remove_outliers_quantile(df_sampleH)
df_sampleI = remove_outliers_quantile(df_sampleI)
df_sampleJ = remove_outliers_quantile(df_sampleJ)
df_sampleK = remove_outliers_quantile(df_sampleK)
df_sampleL = remove_outliers_quantile(df_sampleL)
df_sampleM = remove_outliers_quantile(df_sampleM)
df_sampleN = remove_outliers_quantile(df_sampleN)
df_sampleO = remove_outliers_quantile(df_sampleO)
df_sampleP = remove_outliers_quantile(df_sampleP)
df_sampleQ = remove_outliers_quantile(df_sampleQ)
df_sampleR = remove_outliers_quantile(df_sampleR)
df_sampleS = remove_outliers_quantile(df_sampleS)
df_sampleT = remove_outliers_quantile(df_sampleT)
df_sampleU = remove_outliers_quantile(df_sampleU)
df_sampleV = remove_outliers_quantile(df_sampleV)
df_sampleW = remove_outliers_quantile(df_sampleW)
df_sampleX = remove_outliers_quantile(df_sampleX)

# plot 
sns.histplot(data=data[(data[types_column_name]==typeA)][data_column]).set(title='Original Data',xlim=(-10,10))
plt.show()
sns.histplot(data=df_sampleA).set(title='Data without Outliers',xlim=(-10,10))
plt.show()

# plot 
sns.histplot(data=data[(data[types_column_name]==typeB)][data_column]).set(title='Original Data',xlim=(-10,10))
plt.show()
sns.histplot(data=df_sampleB).set(title='Data without Outliers',xlim=(-10,10))
plt.show()

# plot 
sns.histplot(data=data[(data[types_column_name]==typeC)][data_column]).set(title='Original Data',xlim=(-10,10))
plt.show()
sns.histplot(data=df_sampleC).set(title='Data without Outliers',xlim=(-10,10))
plt.show()

# plot 
sns.histplot(data=data[(data[types_column_name]==typeD)][data_column]).set(title='Original Data',xlim=(-10,10))
plt.show()
sns.histplot(data=df_sampleD).set(title='Data without Outliers',xlim=(-10,10))
plt.show()

# plot 
sns.histplot(data=data[(data[types_column_name]==typeE)][data_column]).set(title='Original Data',xlim=(-10,10))
plt.show()
sns.histplot(data=df_sampleE).set(title='Data without Outliers',xlim=(-10,10))
plt.show()

# plot 
sns.histplot(data=data[(data[types_column_name]==typeF)][data_column]).set(title='Original Data',xlim=(-10,10))
plt.show()
sns.histplot(data=df_sampleF).set(title='Data without Outliers',xlim=(-10,10))
plt.show()

# plot 
sns.histplot(data=data[(data[types_column_name]==typeG)][data_column]).set(title='Original Data',xlim=(-10,10))
plt.show()
sns.histplot(data=df_sampleG).set(title='Data without Outliers',xlim=(-10,10))
plt.show()

# plot 
sns.histplot(data=data[(data[types_column_name]==typeH)][data_column]).set(title='Original Data',xlim=(-10,10))
plt.show()
sns.histplot(data=df_sampleH).set(title='Data without Outliers',xlim=(-10,10))
plt.show()

# plot 
sns.histplot(data=data[(data[types_column_name]==typeI)][data_column]).set(title='Original Data',xlim=(-10,10))
plt.show()
sns.histplot(data=df_sampleI).set(title='Data without Outliers',xlim=(-10,10))
plt.show()

# plot 
sns.histplot(data=data[(data[types_column_name]==typeJ)][data_column]).set(title='Original Data',xlim=(-10,10))
plt.show()
sns.histplot(data=df_sampleJ).set(title='Data without Outliers',xlim=(-10,10))
plt.show()

# plot 
sns.histplot(data=data[(data[types_column_name]==typeK)][data_column]).set(title='Original Data',xlim=(-10,10))
plt.show()
sns.histplot(data=df_sampleK).set(title='Data without Outliers',xlim=(-10,10))
plt.show()

# plot 
sns.histplot(data=data[(data[types_column_name]==typeL)][data_column]).set(title='Original Data',xlim=(-10,10))
plt.show()
sns.histplot(data=df_sampleL).set(title='Data without Outliers',xlim=(-10,10))
plt.show()

# plot 
sns.histplot(data=data[(data[types_column_name]==typeM)][data_column]).set(title='Original Data',xlim=(-10,10))
plt.show()
sns.histplot(data=df_sampleM).set(title='Data without Outliers',xlim=(-10,10))
plt.show()

# plot 
sns.histplot(data=data[(data[types_column_name]==typeN)][data_column]).set(title='Original Data',xlim=(-10,10))
plt.show()
sns.histplot(data=df_sampleN).set(title='Data without Outliers',xlim=(-10,10))
plt.show()

# plot 
sns.histplot(data=data[(data[types_column_name]==typeO)][data_column]).set(title='Original Data',xlim=(-10,10))
plt.show()
sns.histplot(data=df_sampleO).set(title='Data without Outliers',xlim=(-10,10))
plt.show()

# plot 
sns.histplot(data=data[(data[types_column_name]==typeP)][data_column]).set(title='Original Data',xlim=(-10,10))
plt.show()
sns.histplot(data=df_sampleP).set(title='Data without Outliers',xlim=(-10,10))
plt.show()

# plot 
sns.histplot(data=data[(data[types_column_name]==typeQ)][data_column]).set(title='Original Data',xlim=(-10,10))
plt.show()
sns.histplot(data=df_sampleQ).set(title='Data without Outliers',xlim=(-10,10))
plt.show()

# plot 
sns.histplot(data=data[(data[types_column_name]==typeR)][data_column]).set(title='Original Data',xlim=(-10,10))
plt.show()
sns.histplot(data=df_sampleR).set(title='Data without Outliers',xlim=(-10,10))
plt.show()

# plot 
sns.histplot(data=data[(data[types_column_name]==typeS)][data_column]).set(title='Original Data',xlim=(-10,10))
plt.show()
sns.histplot(data=df_sampleS).set(title='Data without Outliers',xlim=(-10,10))
plt.show()

# plot 
sns.histplot(data=data[(data[types_column_name]==typeT)][data_column]).set(title='Original Data',xlim=(-10,10))
plt.show()
sns.histplot(data=df_sampleT).set(title='Data without Outliers',xlim=(-10,10))
plt.show()

# plot 
sns.histplot(data=data[(data[types_column_name]==typeU)][data_column]).set(title='Original Data',xlim=(-10,10))
plt.show()
sns.histplot(data=df_sampleU).set(title='Data without Outliers',xlim=(-10,10))
plt.show()

# plot 
sns.histplot(data=data[(data[types_column_name]==typeV)][data_column]).set(title='Original Data',xlim=(-10,10))
plt.show()
sns.histplot(data=df_sampleV).set(title='Data without Outliers',xlim=(-10,10))
plt.show()

# plot 
sns.histplot(data=data[(data[types_column_name]==typeW)][data_column]).set(title='Original Data',xlim=(-10,10))
plt.show()
sns.histplot(data=df_sampleW).set(title='Data without Outliers',xlim=(-10,10))
plt.show()

# plot 
sns.histplot(data=data[(data[types_column_name]==typeX)][data_column]).set(title='Original Data',xlim=(-10,10))
plt.show()
sns.histplot(data=df_sampleX).set(title='Data without Outliers',xlim=(-10,10))
plt.show()
# Out:
# number of outliers: 0 of 40 observations.
# number of outliers: 3 of 40 observations.
# number of outliers: 0 of 40 observations.
# number of outliers: 1 of 40 observations.
# number of outliers: 0 of 40 observations.
# number of outliers: 3 of 40 observations.
# number of outliers: 0 of 40 observations.
# number of outliers: 1 of 40 observations.
# number of outliers: 0 of 40 observations.
# number of outliers: 6 of 40 observations.
# number of outliers: 0 of 40 observations.
# number of outliers: 5 of 40 observations.
# number of outliers: 4 of 40 observations.
# number of outliers: 1 of 40 observations.
# number of outliers: 8 of 40 observations.
# number of outliers: 4 of 40 observations.
# number of outliers: 3 of 40 observations.
# number of outliers: 0 of 40 observations.
# number of outliers: 0 of 40 observations.
# number of outliers: 5 of 40 observations.
# number of outliers: 1 of 40 observations.
# number of outliers: 1 of 40 observations.
# ...

# %% [markdown]
# Normality Check... Anderson-Darling e outros teste para verificar se amostra segue uma Gaussiana.

# %%
# Anderson-Darling Test
from numpy.random import seed
from numpy.random import randn
from scipy.stats import anderson
# seed the random number generator
seed(1)

print('Package')
# generate univariate observations
data = df['Package']
# normality test
result = anderson(data)
#    H0: the sample has a Gaussian distribution.
#    H1: the sample does not have a Gaussian distribution.

# imprime valor da estatística do test
# e depois a sequencia de valores criticos e alfas possíveis (significante values) 
print('Statistic: %.3f' % result.statistic)
p = 0
for i in range(len(result.critical_values)):
	sl, cv = result.significance_level[i], result.critical_values[i]
	if result.statistic < result.critical_values[i]:
		print('%.3f: %.3f, data looks normal (fail to reject H0)' % (sl, cv))
	else:
		print('%.3f: %.3f, data does not look normal (reject H0)' % (sl, cv))
        
print('GPU')
data = df['GPU']
# normality test
result = anderson(data)
#    H0: the sample has a Gaussian distribution.
#    H1: the sample does not have a Gaussian distribution.

# imprime valor da estatística do test
# e depois a sequencia de valores criticos e alfas possíveis (significante values) 
print('Statistic: %.3f' % result.statistic)
p = 0
for i in range(len(result.critical_values)):
	sl, cv = result.significance_level[i], result.critical_values[i]
	if result.statistic < result.critical_values[i]:
		print('%.3f: %.3f, data looks normal (fail to reject H0)' % (sl, cv))
	else:
		print('%.3f: %.3f, data does not look normal (reject H0)' % (sl, cv))
        
print('Time(sec)')
data = df['Time(sec)']
# normality test
result = anderson(data)
#    H0: the sample has a Gaussian distribution.
#    H1: the sample does not have a Gaussian distribution.

# imprime valor da estatística do test
# e depois a sequencia de valores criticos e alfas possíveis (significante values) 
print('Statistic: %.3f' % result.statistic)
p = 0
for i in range(len(result.critical_values)):
	sl, cv = result.significance_level[i], result.critical_values[i]
	if result.statistic < result.critical_values[i]:
		print('%.3f: %.3f, data looks normal (fail to reject H0)' % (sl, cv))
	else:
		print('%.3f: %.3f, data does not look normal (reject H0)' % (sl, cv))
        
print('Peak Memory Usage (KB)')
data = df['Peak Memory Usage (KB)']
# normality test
result = anderson(data)
#    H0: the sample has a Gaussian distribution.
#    H1: the sample does not have a Gaussian distribution.

# imprime valor da estatística do test
# e depois a sequencia de valores criticos e alfas possíveis (significante values) 
print('Statistic: %.3f' % result.statistic)
p = 0
for i in range(len(result.critical_values)):
	sl, cv = result.significance_level[i], result.critical_values[i]
	if result.statistic < result.critical_values[i]:
		print('%.3f: %.3f, data looks normal (fail to reject H0)' % (sl, cv))
	else:
		print('%.3f: %.3f, data does not look normal (reject H0)' % (sl, cv))
# Out:
# Package
# Statistic: 110.010
# 15.000: 0.574, data does not look normal (reject H0)
# 10.000: 0.653, data does not look normal (reject H0)
# 5.000: 0.784, data does not look normal (reject H0)
# 2.500: 0.914, data does not look normal (reject H0)
# 1.000: 1.087, data does not look normal (reject H0)
# GPU
# Statistic: 202.744
# 15.000: 0.574, data does not look normal (reject H0)
# 10.000: 0.653, data does not look normal (reject H0)
# 5.000: 0.784, data does not look normal (reject H0)
# 2.500: 0.914, data does not look normal (reject H0)
# 1.000: 1.087, data does not look normal (reject H0)
# Time(sec)
# Statistic: 111.817
# 15.000: 0.574, data does not look normal (reject H0)
# 10.000: 0.653, data does not look normal (reject H0)
# 5.000: 0.784, data does not look normal (reject H0)
# 2.500: 0.914, data does not look normal (reject H0)
# 1.000: 1.087, data does not look normal (reject H0)
# Peak Memory Usage (KB)
# Statistic: 6.366
# ...

# %% [markdown]
# Calcular um empirical pvalue para um teste de médias entre o desempenho de dois algoritmos

# %%
# Clustering com kmeans
from sklearn.cluster import KMeans
from matplotlib.lines import Line2D

file_name = 'final.csv'
df = df = pd.read_csv(file_name, header = 0, delimiter=",", decimal=".", names=['Program','Package','Core(s)','GPU','DRAM?','Time(sec)','Peak Memory Usage (KB)','PowerCap(uW)'])

# preprocessa categoricos com one hot encoding
df = pd.get_dummies(df, columns=["Program"])  

#k means
kmeans = KMeans(n_clusters=3, random_state=0,n_init=10)
#get centroids
df['cluster'] = kmeans.fit_predict(df)


centroids = kmeans.cluster_centers_
cen_x = [i[0] for i in centroids] 
cen_y = [i[1] for i in centroids]
## add to df
df['cen_x'] = df.cluster.map({0:cen_x[0], 1:cen_x[1], 2:cen_x[2]})
df['cen_y'] = df.cluster.map({0:cen_y[0], 1:cen_y[1], 2:cen_y[2]})
#define and map colors
colors = ['#DF2020', '#81DF20', '#2095DF']
df['c'] = df.cluster.map({0:colors[0], 1:colors[1], 2:colors[2]})

plt.figure(figsize=(12,6))
plt.scatter(df.GPU, df.Package, c=df.c, alpha = 0.6)

# create a list of legend elem
## markers / records
legend_elements = [Line2D([0], [0], marker='o', color='w', 
                          label='Cluster {}'.format(i+1), 
               markerfacecolor=mcolor, markersize=5) 
for i, mcolor in enumerate(colors)]

# plot legend
plt.legend(handles=legend_elements, loc='upper right')

# title and labels
plt.title('Comparing Algorithms', loc='left', fontsize=22)
plt.xlabel('Package')
plt.ylabel('GPU')
# Out:
# Text(0, 0.5, 'GPU')
